# %%
# %run Assignment6Part1.py

# %%
# %run Assignment6Part2.py
# Out:
# orig x_train shape: (4999, 32, 32, 3)
# Model: "sequential_129"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_516 (Conv2D)          (None, 32, 32, 16)        448
# _________________________________________________________________
# conv2d_517 (Conv2D)          (None, 16, 16, 16)        2320
# _________________________________________________________________
# conv2d_518 (Conv2D)          (None, 16, 16, 32)        4640
# _________________________________________________________________
# conv2d_519 (Conv2D)          (None, 8, 8, 32)          9248
# _________________________________________________________________
# dropout_129 (Dropout)        (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_129 (Flatten)        (None, 2048)              0
# _________________________________________________________________
# ...

# %%
# %run Assignment6Part3.py
# Out:
# orig x_train shape: (4999, 32, 32, 3)
# Model: "sequential_111"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_444 (Conv2D)          (None, 32, 32, 16)        448
# _________________________________________________________________
# conv2d_445 (Conv2D)          (None, 16, 16, 16)        2320
# _________________________________________________________________
# conv2d_446 (Conv2D)          (None, 16, 16, 32)        4640
# _________________________________________________________________
# conv2d_447 (Conv2D)          (None, 8, 8, 32)          9248
# _________________________________________________________________
# dropout_111 (Dropout)        (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_111 (Flatten)        (None, 2048)              0
# _________________________________________________________________
# ...
